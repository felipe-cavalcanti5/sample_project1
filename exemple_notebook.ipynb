# %%
print('Hello, World!')
# Out:
# Hello, World!

# %%
a = 5

# %%
a = 6

# %%
a
# Out:
# 6

# %% [markdown]
# ## Heart disiase project
# This Poject is about classifying whether or not a patient has heart disease.

# %%
import pandas as pd

# %%
df = pd.read_csv("011 heart-disease.csv")

# %% [markdown]
# The following table shows heart disease information for patients.

# %%
df.head(5)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df.target.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='target'>

# %% [markdown]
# ![](011 6-step-ml-framework.png)

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ![](011-6-step-ml-framework.png)

# %% [markdown]
# ## 1. Problem Definition
# Predict heart disease.

# %% [markdown]
# ## 2. Data
# This is the data we're using.

# %%
ls
# Out:
#  O volume na unidade C nÆo tem nome.
#  O N£mero de S‚rie do Volume ‚ 42C5-4F0D
#
#  Pasta de C:\miniconda3\sample_project1
#
# 22/08/2026  15:30    <DIR>          .
# 22/08/2026  15:30    <DIR>          ..
# 22/08/2026  15:17    <DIR>          .ipynb_checkpoints
# 22/08/2026  11:21            11.328 011 heart-disease.csv
# 22/08/2026  11:23           332.025 011-6-step-ml-framework.png
# 21/08/2026  18:20    <DIR>          env
# 22/08/2026  15:30            22.268 exemple_notebook.ipynb
# 21/08/2026  18:32             1.372 Untitled.ipynb
#                4 arquivo(s)        366.993 bytes
#                4 pasta(s)   622.173.511.680 bytes dispon¡veis

# %%
# !ls
# Out:
# 'ls' nÆo ‚ reconhecido como um comando interno
# ou externo, um programa oper vel ou um arquivo em lotes.

# %%
ls
# Out:
#  O volume na unidade C nÆo tem nome.
#  O N£mero de S‚rie do Volume ‚ 42C5-4F0D
#
#  Pasta de C:\miniconda3\sample_project1
#
# 22/08/2026  15:30    <DIR>          .
# 22/08/2026  15:30    <DIR>          ..
# 22/08/2026  15:17    <DIR>          .ipynb_checkpoints
# 22/08/2026  11:21            11.328 011 heart-disease.csv
# 22/08/2026  11:23           332.025 011-6-step-ml-framework.png
# 21/08/2026  18:20    <DIR>          env
# 22/08/2026  15:30            22.268 exemple_notebook.ipynb
# 21/08/2026  18:32             1.372 Untitled.ipynb
#                4 arquivo(s)        366.993 bytes
#                4 pasta(s)   622.173.708.288 bytes dispon¡veis
